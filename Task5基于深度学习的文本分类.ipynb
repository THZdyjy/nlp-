# %%
import logging
import random

import numpy as np
import torch

logging.basicConfig(level=logging.INFO, format='%(asctime)-15s %(levelname)s: %(message)s')

# set seed 
seed = 666
random.seed(seed)
np.random.seed(seed)
torch.cuda.manual_seed(seed)
torch.manual_seed(seed)

# %%
# split data to 10 fold
fold_num = 10
data_file = './train_set.csv'
import pandas as pd


def all_data2fold(fold_num, num=10000):
    fold_data = []
    f = pd.read_csv(data_file, sep='\t', encoding='UTF-8')
    texts = f['text'].tolist()[:num]
    labels = f['label'].tolist()[:num]

    total = len(labels)

    index = list(range(total))
    np.random.shuffle(index)

    all_texts = []
    all_labels = []
    for i in index:
        all_texts.append(texts[i])
        all_labels.append(labels[i])

    label2id = {}
    for i in range(total):
        label = str(all_labels[i])
        if label not in label2id:
            label2id[label] = [i]
        else:
            label2id[label].append(i)

    all_index = [[] for _ in range(fold_num)]
    for label, data in label2id.items():
        # print(label, len(data))
        batch_size = int(len(data) / fold_num)
        other = len(data) - batch_size * fold_num
        for i in range(fold_num):
            cur_batch_size = batch_size + 1 if i < other else batch_size
            # print(cur_batch_size)
            batch_data = [data[i * batch_size + b] for b in range(cur_batch_size)]
            all_index[i].extend(batch_data)

    batch_size = int(total / fold_num)
    other_texts = []
    other_labels = []
    other_num = 0
    start = 0
    for fold in range(fold_num):
        num = len(all_index[fold])
        texts = [all_texts[i] for i in all_index[fold]]
        labels = [all_labels[i] for i in all_index[fold]]

        if num > batch_size:
            fold_texts = texts[:batch_size]
            other_texts.extend(texts[batch_size:])
            fold_labels = labels[:batch_size]
            other_labels.extend(labels[batch_size:])
            other_num += num - batch_size
        elif num < batch_size:
            end = start + batch_size - num
            fold_texts = texts + other_texts[start: end]
            fold_labels = labels + other_labels[start: end]
            start = end
        else:
            fold_texts = texts
            fold_labels = labels

        assert batch_size == len(fold_labels)

        # shuffle
        index = list(range(batch_size))
        np.random.shuffle(index)

        shuffle_fold_texts = []
        shuffle_fold_labels = []
        for i in index:
            shuffle_fold_texts.append(fold_texts[i])
            shuffle_fold_labels.append(fold_labels[i])

        data = {'label': shuffle_fold_labels, 'text': shuffle_fold_texts}
        fold_data.append(data)

    logging.info("Fold lens %s", str([len(data['label']) for data in fold_data]))

    return fold_data


fold_data = all_data2fold(10)
# Out:
# 2020-07-31 07:12:36,363 INFO: Fold lens [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %%
# build train data for word2vec
fold_id = 9

train_texts = []
for i in range(0, fold_id):
    data = fold_data[i]
    train_texts.extend(data['text'])
    
logging.info('Total %d docs.' % len(train_texts))
# Out:
# 2020-07-31 07:12:36,488 INFO: Total 9000 docs.

# %%
logging.info('Start training...')
from gensim.models.word2vec import Word2Vec

num_features = 100     # Word vector dimensionality
num_workers = 8       # Number of threads to run in parallel

train_texts = list(map(lambda x: list(x.split()), train_texts))
model = Word2Vec(train_texts, workers=num_workers, size=num_features)
model.init_sims(replace=True)

# save model
model.save("./word2vec.bin")
# Out:
# 2020-07-31 07:12:36,497 INFO: Start training...
# 2020-07-31 07:12:38,465 INFO: collecting all words and their counts
# 2020-07-31 07:12:38,466 INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-07-31 07:12:39,878 INFO: collected 5295 word types from a corpus of 8191447 raw words and 9000 sentences
# 2020-07-31 07:12:39,878 INFO: Loading a fresh vocabulary
# 2020-07-31 07:12:39,937 INFO: effective_min_count=5 retains 4335 unique words (81% of original 5295, drops 960)
# 2020-07-31 07:12:39,937 INFO: effective_min_count=5 leaves 8189498 word corpus (99% of original 8191447, drops 1949)
# 2020-07-31 07:12:39,950 INFO: deleting the raw counts dictionary of 5295 items
# 2020-07-31 07:12:39,951 INFO: sample=0.001 downsamples 61 most-common words
# 2020-07-31 07:12:39,952 INFO: downsampling leaves estimated 7070438 word corpus (86.3% of prior 8189498)
# 2020-07-31 07:12:39,959 INFO: estimated required memory for 4335 words and 100 dimensions: 5635500 bytes
# 2020-07-31 07:12:39,960 INFO: resetting layer weights
# 2020-07-31 07:12:40,604 INFO: training model with 8 workers on 4335 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-07-31 07:12:41,610 INFO: EPOCH 1 - PROGRESS: at 47.33% examples, 3313111 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:42,617 INFO: EPOCH 1 - PROGRESS: at 94.32% examples, 3306305 words/s, in_qsize 13, out_qsize 2
# 2020-07-31 07:12:42,722 INFO: worker thread finished; awaiting finish of 7 more threads
# 2020-07-31 07:12:42,723 INFO: worker thread finished; awaiting finish of 6 more threads
# 2020-07-31 07:12:42,724 INFO: worker thread finished; awaiting finish of 5 more threads
# 2020-07-31 07:12:42,724 INFO: worker thread finished; awaiting finish of 4 more threads
# 2020-07-31 07:12:42,728 INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-31 07:12:42,731 INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-31 07:12:42,732 INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-31 07:12:42,737 INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-31 07:12:42,737 INFO: EPOCH - 1 : training on 8191447 raw words (7022328 effective words) took 2.1s, 3299009 effective words/s
# 2020-07-31 07:12:43,747 INFO: EPOCH 2 - PROGRESS: at 45.29% examples, 3168070 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:44,750 INFO: EPOCH 2 - PROGRESS: at 92.17% examples, 3227320 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:44,903 INFO: worker thread finished; awaiting finish of 7 more threads
# 2020-07-31 07:12:44,904 INFO: worker thread finished; awaiting finish of 6 more threads
# 2020-07-31 07:12:44,905 INFO: worker thread finished; awaiting finish of 5 more threads
# 2020-07-31 07:12:44,905 INFO: worker thread finished; awaiting finish of 4 more threads
# 2020-07-31 07:12:44,908 INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-31 07:12:44,910 INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-31 07:12:44,919 INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-31 07:12:44,920 INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-31 07:12:44,920 INFO: EPOCH - 2 : training on 8191447 raw words (7021032 effective words) took 2.2s, 3221385 effective words/s
# 2020-07-31 07:12:45,929 INFO: EPOCH 3 - PROGRESS: at 40.41% examples, 2832864 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:46,930 INFO: EPOCH 3 - PROGRESS: at 85.90% examples, 3012176 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:47,239 INFO: worker thread finished; awaiting finish of 7 more threads
# 2020-07-31 07:12:47,245 INFO: worker thread finished; awaiting finish of 6 more threads
# 2020-07-31 07:12:47,246 INFO: worker thread finished; awaiting finish of 5 more threads
# 2020-07-31 07:12:47,247 INFO: worker thread finished; awaiting finish of 4 more threads
# 2020-07-31 07:12:47,252 INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-31 07:12:47,253 INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-31 07:12:47,256 INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-31 07:12:47,257 INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-31 07:12:47,258 INFO: EPOCH - 3 : training on 8191447 raw words (7021797 effective words) took 2.3s, 3007834 effective words/s
# 2020-07-31 07:12:48,262 INFO: EPOCH 4 - PROGRESS: at 44.11% examples, 3109913 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:49,265 INFO: EPOCH 4 - PROGRESS: at 89.98% examples, 3160321 words/s, in_qsize 14, out_qsize 1
# 2020-07-31 07:12:49,471 INFO: worker thread finished; awaiting finish of 7 more threads
# 2020-07-31 07:12:49,472 INFO: worker thread finished; awaiting finish of 6 more threads
# 2020-07-31 07:12:49,472 INFO: worker thread finished; awaiting finish of 5 more threads
# 2020-07-31 07:12:49,473 INFO: worker thread finished; awaiting finish of 4 more threads
# 2020-07-31 07:12:49,473 INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-31 07:12:49,479 INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-31 07:12:49,483 INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-31 07:12:49,484 INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-31 07:12:49,484 INFO: EPOCH - 4 : training on 8191447 raw words (7022226 effective words) took 2.2s, 3158663 effective words/s
# 2020-07-31 07:12:50,490 INFO: EPOCH 5 - PROGRESS: at 45.49% examples, 3195824 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:51,494 INFO: EPOCH 5 - PROGRESS: at 91.30% examples, 3200352 words/s, in_qsize 15, out_qsize 0
# 2020-07-31 07:12:51,674 INFO: worker thread finished; awaiting finish of 7 more threads
# 2020-07-31 07:12:51,675 INFO: worker thread finished; awaiting finish of 6 more threads
# 2020-07-31 07:12:51,675 INFO: worker thread finished; awaiting finish of 5 more threads
# 2020-07-31 07:12:51,680 INFO: worker thread finished; awaiting finish of 4 more threads
# 2020-07-31 07:12:51,680 INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-07-31 07:12:51,685 INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-07-31 07:12:51,686 INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-07-31 07:12:51,688 INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-07-31 07:12:51,689 INFO: EPOCH - 5 : training on 8191447 raw words (7023240 effective words) took 2.2s, 3189883 effective words/s
# 2020-07-31 07:12:51,690 INFO: training on a 40957235 raw words (35110623 effective words) took 11.1s, 3167572 effective words/s
# 2020-07-31 07:12:51,690 INFO: precomputing L2-norms of word weight vectors
# 2020-07-31 07:12:51,691 INFO: saving Word2Vec object under ./word2vec.bin, separately None
# 2020-07-31 07:12:51,692 INFO: not storing attribute vectors_norm
# 2020-07-31 07:12:51,693 INFO: not storing attribute cum_table
# 2020-07-31 07:12:51,726 INFO: saved ./word2vec.bin
